# %%
import pandas as pd

# %%
songs = pd.read_csv("tracks.csv")

# %%
songs.shape[0]
# Out:
# 586672

# %%
songs.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
songs[songs['release_date'].isin(sorted(songs['release_date'].unique())[-5:])]
# Out:
#                             id  \
# 86695   0usLN2VpccZQwWkGLm3Odm
# 92812   2spPLfhb8c7rPxz28IdeXR
# 92864   1Nlstdx5q4GVUyaQqHYvqh
# 93457   2R0j15lZVbiZulnhJGEjQ5
# 93459   0OYcjececNh1p8mSmmRhsf
# ...                        ...
# 576120  3CVhUOyoJwz7LClZwNSHR3
# 576122  7bBXvNPlkfwk8Y4azhxm4O
# 576123  1isEADg1EJ9dqQUjsHjOhS
# 576124  3MXopdUtwhQPxDOdj39oDA
# 576125  6ILjkEufgyZ7NyLnrpr6zr
#
#                                                      name  popularity  \
# 86695                                2013 Will Be My Year           0
# 92812   A State Of Trance (ASOT 1012) - ASOT Yearmix 2...           0
# 92864                     Inner City Life - 2020 Remaster           0
# 93457                                 2020 Year of Vision           0
# 93459                                 2020 Year of Vision           0
# ...                                                   ...         ...
# 576120                                Talking to the Moon           0
# ...

# %%
songs[(songs['artists'] == "['BLACKPINK']")]
# Out:
#                             id                  name  popularity  duration_ms  \
# 89062   13MF2TYuyfITClL1R2ei6e             BOOMBAYAH          76       240793
# 89118   7qmvLmX9tyaTiBAVNI6YEn     PLAYING WITH FIRE          75       197289
# 89150   6NEoeBLQbOMw92qMeLfI40               WHISTLE          74       211632
# 89386   3tP6QKbXvtrxiDI7QwKyUf                  STAY          70       230323
# 90120   4ZxOuNHhpyOj4gv52MtQpT  As If It's Your Last          77       213264
# ...                        ...                   ...         ...          ...
# 562661  3VTKwL1uS2JGotaJA4oXXB         Pretty Savage          56       199122
# 562823  09JE599HkmbidwGWyD4ZGy       Love To Hate Me          51       169798
# 562844  4yOqfpzmL4FvmXJTUgAMUP        Crazy Over You          51       161946
# 562875  78VxuxuTcKnhxEDtncc1QS     How You Like That          50       181307
# 562893  1b0PG9Zd1HhOwq3n9QNkDg        You Never Know          50       229202
#
# ...

# %%
artists = pd.read_csv("artists.csv")

# %%
artists.shape[0]
# Out:
# 1104349

# %%
artists[artists['name'] == 'Drake']
# Out:
#                             id   followers  \
# 313676  3TVXtAsR1Inumwj472S9r4  54416812.0
# 594686  2m5ti7YuYYCVs8xfZgnVkx     13606.0
# 594690  4PrHn62sbAwEY2TkPYXOxN        27.0
#
#                                                    genres   name  popularity
# 313676  ['canadian hip hop', 'canadian pop', 'hip hop'...  Drake          98
# 594686                                                 []  Drake          12
# 594690                                                 []  Drake           2
